# %% [markdown]
# # Valorant YOLO26 Tracking Test
#
# - load weight `best_valorant.pt`

# %%
# %pip install ultralytics
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached markupsafe-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.7 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 33.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 18.5 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 3.7 MB/s  0:00:21m0:00:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 3.6 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 2.0 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.2 MB/s  0:00:00 eta 0:00:01
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 96361, done.
# remote: Counting objects: 100% (1110/1110), done.
# remote: Compressing objects: 100% (473/473), done.
# remote: Total 96361 (delta 971), reused 637 (delta 637), pack-reused 95251 (from 5)
# Receiving objects: 100% (96361/96361), 52.28 MiB | 4.88 MiB/s, done.
# Resolving deltas: 100% (72134/72134), done.

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="t26FCk1ycEkreivDlskz")
project = rf.workspace("daniels-magonis-0pjzx").project("valorant-9ufcp")
version = project.version(3)
dataset = version.download("yolo26")

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="t26FCk1ycEkreivDlskz")
project = rf.workspace("fps").project("valorant-gygiq")
version = project.version(6)
dataset = version.download("yolo26")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Valorant-6 in yolo26:: 100%|██████████| 10416/10416 [00:00<00:00, 12817.38it/s]

# %%
from ultralytics import YOLO

trained_model_path = 'best_valorant.pt'
model = YOLO(trained_model_path)

model.val(data='/Users/luongnhatkhoi/Desktop/YOLO26s_Valorant_Tracking/valorant-6/data.yaml',
          imgsz=640,
          split='test')
# Out:
# Ultralytics 8.4.37 🚀 Python-3.14.3 torch-2.11.0 CPU (Apple M4 Pro)
# YOLO26s summary (fused): 122 layers, 9,465,954 parameters, 0 gradients, 20.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2074.6±839.5 MB/s, size: 60.5 KB)
# val: Scanning /Users/luongnhatkhoi/Desktop/YOLO26s_Valorant_Tracking/valorant-6/test/labels... 475 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 475/475 5.2Kit/s 0.1s
# val: New cache created: /Users/luongnhatkhoi/Desktop/YOLO26s_Valorant_Tracking/valorant-6/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4s/it 2:134.4ss
#                    all        475        494      0.962      0.942      0.985      0.754
#                      0        158        172      0.959      0.953      0.984      0.769
#                      1        317        322      0.965       0.93      0.986      0.739
# ...

# %%
# %pip install yt-dlp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.9 MB/s  0:00:00 eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO('best_valorant.pt') 
utube_link = 'https://youtu.be/RMdDGWQRzvc?si=8uNZx9jg2YUF7m6u'

results = model.track(
    source=utube_link, 
    show=True,
    save=True,
    tracker='bytetrack.yaml',
    device='mps',
    stream=True
)

for r in results:
    pass
# Out:
# 1/1: https://youtu.be/RMdDGWQRzvc?si=8uNZx9jg2YUF7m6u... Success ✅ (33628 frames of shape 1920x1080 at 59.94 FPS)
#
# 0: 384x640 (no detections), 10.1ms
# 0: 384x640 (no detections), 9.0ms
# 0: 384x640 (no detections), 9.6ms
# 0: 384x640 (no detections), 10.3ms
# 0: 384x640 (no detections), 13.8ms
# 0: 384x640 (no detections), 14.5ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 384x640 (no detections), 16.2ms
# 0: 384x640 (no detections), 10.2ms
# 0: 384x640 (no detections), 10.1ms
# 0: 384x640 (no detections), 10.8ms
# 0: 384x640 (no detections), 10.7ms
# 0: 384x640 (no detections), 11.2ms
# 0: 384x640 (no detections), 10.6ms
# 0: 384x640 (no detections), 10.9ms
# 0: 384x640 (no detections), 11.4ms
# 0: 384x640 (no detections), 10.7ms
# 0: 384x640 (no detections), 11.9ms
# 0: 384x640 (no detections), 13.5ms
# 0: 384x640 (no detections), 12.2ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# ...
